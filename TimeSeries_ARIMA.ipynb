# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf,pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# %%
import os
os.chdir('C:\\Users\\admin\\Downloads')

# %%
dataset = pd.read_csv('AirPassengers.csv')

# %%
dataset.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
dataset['Month'] = pd.to_datetime(dataset['Month'],infer_datetime_format=True) #convert from string to datetime
indexedDataset = dataset.set_index(['Month'])
indexedDataset.head(5)
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
#plot_graph
plt.xlabel('Date')
plt.ylabel('Nuber of air passengers')
plt.plot(indexedDataset)

# %%
#Determine rolling statistics
rolmean = indexedDataset.rolling(window=12).mean() 
rolstd = indexedDataset.rolling(window=12).std()
print(rolmean,rolstd)
# Out:
#             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# ...                 ...
# 1960-08-01   463.333333
# 1960-09-01   467.083333
# 1960-10-01   471.583333
# 1960-11-01   473.916667
# 1960-12-01   476.166667
#
# [144 rows x 1 columns]             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# ...                 ...
# 1960-08-01    83.630500
# 1960-09-01    84.617276
# 1960-10-01    82.541954
# 1960-11-01    79.502382
# 1960-12-01    77.737125
#
# [144 rows x 1 columns]

# %%
#Plot rolling statistics 
orig = plt.plot(indexedDataset, color='blue', label='Original')
plt.plot(rolmean, color = 'red', label ='Rolling Mean')
plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
#Perform Augmented Dicke-Fuller test:
print('Results of Dicket Fuller Test:')
dftest = adfuller(indexedDataset['#Passengers'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index =['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
  dfoutput['Critical Value (%s)'%key] = value

print(dfoutput)
# Out:
# Results of Dicket Fuller Test:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %%
#Estimating Trend
indexedDataset_logScale = np.log(indexedDataset)
plt.plot(indexedDataset_logScale)

# %%
#The below transformation is required to make series stationary
movingAverage = indexedDataset_logScale.rolling(window=12).mean()
movingSTD = indexedDataset_logScale.rolling(window=12).std()
plt.plot(indexedDataset_logScale)
plt.plot(movingAverage, color='red')

# %%
datasetLogScaleMinusMovingAverage = indexedDataset_logScale - movingAverage
datasetLogScaleMinusMovingAverage.head(12)

#Remove NAN values
datasetLogScaleMinusMovingAverage.dropna(inplace=True)
datasetLogScaleMinusMovingAverage.head(10)
# Out:
#             #Passengers
# Month
# 1949-12-01    -0.065494
# 1950-01-01    -0.093449
# 1950-02-01    -0.007566
# 1950-03-01     0.099416
# 1950-04-01     0.052142
# 1950-05-01    -0.027529
# 1950-06-01     0.139881
# 1950-07-01     0.260184
# 1950-08-01     0.248635
# 1950-09-01     0.162937

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
        #Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test:')
    dftest = adfuller(timeseries['#Passengers'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(datasetLogScaleMinusMovingAverage)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                  -3.162908
# p-value                          0.022235
# #Lags Used                      13.000000
# Number of Observations Used    119.000000
# Critical Value (1%)             -3.486535
# Critical Value (5%)             -2.886151
# Critical Value (10%)            -2.579896
# dtype: float64

# %% [markdown]
# Exponential Decay Transformation

# %%
exponentialDecayWeightedAverage = indexedDataset_logScale.ewm(halflife=12, min_periods=0, adjust= True).mean()
plt.plot(indexedDataset_logScale)
plt.plot(exponentialDecayWeightedAverage, color='red')

# %%
datasetLogScaleMinusMovingAverage = indexedDataset_logScale - exponentialDecayWeightedAverage
test_stationarity(datasetLogScaleMinusMovingAverage)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                  -3.601262
# p-value                          0.005737
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# Time Shift Transformation

# %%
datasetLogDiffShifting = indexedDataset_logScale - indexedDataset_logScale.shift()
plt.plot(datasetLogDiffShifting)

# %%
datasetLogDiffShifting.dropna(inplace=True)
test_stationarity(datasetLogDiffShifting)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                  -2.717131
# p-value                          0.071121
# #Lags Used                      14.000000
# Number of Observations Used    128.000000
# Critical Value (1%)             -3.482501
# Critical Value (5%)             -2.884398
# Critical Value (10%)            -2.578960
# dtype: float64

# %%
decomposition = seasonal_decompose(indexedDataset_logScale) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(indexedDataset_logScale, label='Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')

plt.subplot(411)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')

plt.subplot(411)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')

plt.tight_layout()

#there can be cases where an observation simply consisted of trend & seasonality. In that case, there won't be 
#any residual component & that would be a null or NaN. Hence, we also remove such cases.
decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
test_stationarity(decomposedLogData)
# Out:
# Results of Dickey Fuller Test:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: #Passengers
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     660             try:
# --> 661                 parsed, reso = self._parse_with_reso(key)
#     662             except ValueError as err:
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\indexes\datetimelike.py in _parse_with_reso(self, label)
#     235             freq = getattr(self, "freqstr", getattr(self, "inferred_freq", None))
# --> 236         parsed, reso_str = parsing.parse_time_string(label, freq)
#     237         reso = Resolution.from_attrname(reso_str)
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_time_string()
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# DateParseError: Unknown datetime string format, unable to parse: #Passengers
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\3756588834.py in <module>
#      27 decomposedLogData = residual
#      28 decomposedLogData.dropna(inplace=True)
# ---> 29 test_stationarity(decomposedLogData)
#
# ~\AppData\Local\Temp\ipykernel_10076\2997919540.py in test_stationarity(timeseries)
#      14         #Perform Dickey–Fuller test:
#      15     print('Results of Dickey Fuller Test:')
# ---> 16     dftest = adfuller(timeseries['#Passengers'], autolag='AIC')
#      17     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#      18     for key,value in dftest[4].items():
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     661                 parsed, reso = self._parse_with_reso(key)
#     662             except ValueError as err:
# --> 663                 raise KeyError(key) from err
#     664
#     665             if self._can_partial_date_slice(reso):
#
# KeyError: '#Passengers'

# %%
decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
test_stationarity(decomposedLogData)
# Out:
# Results of Dickey Fuller Test:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: #Passengers
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     660             try:
# --> 661                 parsed, reso = self._parse_with_reso(key)
#     662             except ValueError as err:
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\indexes\datetimelike.py in _parse_with_reso(self, label)
#     235             freq = getattr(self, "freqstr", getattr(self, "inferred_freq", None))
# --> 236         parsed, reso_str = parsing.parse_time_string(label, freq)
#     237         reso = Resolution.from_attrname(reso_str)
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_time_string()
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# DateParseError: Unknown datetime string format, unable to parse: #Passengers
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\3837449935.py in <module>
#       1 decomposedLogData = residual
#       2 decomposedLogData.dropna(inplace=True)
# ----> 3 test_stationarity(decomposedLogData)
#
# ~\AppData\Local\Temp\ipykernel_10076\2997919540.py in test_stationarity(timeseries)
#      14         #Perform Dickey–Fuller test:
#      15     print('Results of Dickey Fuller Test:')
# ---> 16     dftest = adfuller(timeseries['#Passengers'], autolag='AIC')
#      17     dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
#      18     for key,value in dftest[4].items():
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     661                 parsed, reso = self._parse_with_reso(key)
#     662             except ValueError as err:
# --> 663                 raise KeyError(key) from err
#     664
#     665             if self._can_partial_date_slice(reso):
#
# KeyError: '#Passengers'

# %% [markdown]
# Plotting ACF & PACF

# %%
#ACF & PACF plots

lag_acf = acf(datasetLogDiffShifting, nlags=20)
lag_pacf = pacf(datasetLogDiffShifting, nlags=20, method='ols')

#Plot ACF:
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.title('Autocorrelation Function')            

#Plot PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.title('Partial Autocorrelation Function')
            
plt.tight_layout()

# %% [markdown]
# Building Models

# %%
#AR Model
#making order=(2,1,0) gives RSS=1,5023
model = ARIMA(indexedDataset_logScale, order=(2,1,0))
results_AR = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_AR.fittedvalues - datasetLogDiffShifting['#Passengers'])**2))
print('Plotting AR model')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\3895829349.py in <module>
#       1 #AR Model
#       2 #making order=(2,1,0) gives RSS=1,5023
# ----> 3 model = ARIMA(indexedDataset_logScale, order=(2,1,0))
#       4 results_AR = model.fit(disp=-1)
#       5 plt.plot(datasetLogDiffShifting)
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
#MA Model
model = ARIMA(indexedDataset_logScale, order=(0,1,2))
results_MA = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_MA.fittedvalues - datasetLogDiffShifting['#Passengers'])**2))
print('Plotting MA model')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\4090583571.py in <module>
#       1 #MA Model
# ----> 2 model = ARIMA(indexedDataset_logScale, order=(0,1,2))
#       3 results_MA = model.fit(disp=-1)
#       4 plt.plot(datasetLogDiffShifting)
#       5 plt.plot(results_MA.fittedvalues, color='red')
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
#AR+I+MA = ARIMA model
model = ARIMA(indexedDataset_logScale, order=(2,1,2))
results_ARIMA = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_ARIMA.fittedvalues - datasetLogDiffShifting['#Passengers'])**2))
print('Plotting ARIMA model')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\1976699482.py in <module>
#       1 #AR+I+MA = ARIMA model
# ----> 2 model = ARIMA(indexedDataset_logScale, order=(2,1,2))
#       3 results_ARIMA = model.fit(disp=-1)
#       4 plt.plot(datasetLogDiffShifting)
#       5 plt.plot(results_ARIMA.fittedvalues, color='red')
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %% [markdown]
# Prediction & Reverse Transformations

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\1441545371.py in <module>
# ----> 1 predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
#       2 print(predictions_ARIMA_diff.head())
#
# NameError: name 'results_ARIMA' is not defined

# %%
#Convert to cumulative sum
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\3045387745.py in <module>
#       1 #Convert to cumulative sum
# ----> 2 predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
#       3 print(predictions_ARIMA_diff_cumsum)
#
# NameError: name 'predictions_ARIMA_diff' is not defined

# %%
predictions_ARIMA_log = pd.Series(indexedDataset_logScale['#Passengers'].iloc[0], index=indexedDataset_logScale.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
predictions_ARIMA_log.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\2099992323.py in <module>
#       1 predictions_ARIMA_log = pd.Series(indexedDataset_logScale['#Passengers'].iloc[0], index=indexedDataset_logScale.index)
# ----> 2 predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value=0)
#       3 predictions_ARIMA_log.head()
#
# NameError: name 'predictions_ARIMA_diff_cumsum' is not defined

# %%
#Inverse of log is exp
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(indexedDataset)
plt.plot(predictions_ARIMA)

# %%
indexedDataset_logScale
# Out:
#             #Passengers
# Month
# 1949-01-01     4.718499
# 1949-02-01     4.770685
# 1949-03-01     4.882802
# 1949-04-01     4.859812
# 1949-05-01     4.795791
# ...                 ...
# 1960-08-01     6.406880
# 1960-09-01     6.230481
# 1960-10-01     6.133398
# 1960-11-01     5.966147
# 1960-12-01     6.068426
#
# [144 rows x 1 columns]

# %%
#We have 144(existing data of 12 yrs in months) data points. 
#And we want to forecast for additional 120 data points or 10 yrs.
results_ARIMA.plot_predict(1,264) 
#x=results_ARIMA.forecast(steps=120)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10076\1991741440.py in <module>
#       1 #We have 144(existing data of 12 yrs in months) data points.
#       2 #And we want to forecast for additional 120 data points or 10 yrs.
# ----> 3 results_ARIMA.plot_predict(1,264)
#       4 #x=results_ARIMA.forecast(steps=120)
#
# NameError: name 'results_ARIMA' is not defined
